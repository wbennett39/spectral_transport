# %%
using Pkg
Pkg.build("PyCall")
# Out:
#    Resolving package versions...
#    Installed PyPlot ──────────── v2.11.6
#    Installed FixedPointNumbers ─ v0.8.5
#    Installed ColorTypes ──────── v0.12.1
#    Installed Colors ──────────── v0.13.0
#     Updating `/opt/anaconda3/share/julia/environments/anaconda3/Project.toml`
#   [d330b81b] + PyPlot v2.11.6
#     Updating `/opt/anaconda3/share/julia/environments/anaconda3/Manifest.toml`
#   [3da002f7] + ColorTypes v0.12.1
#   [5ae59095] + Colors v0.13.0
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [d330b81b] + PyPlot v2.11.6
#   [189a3867] + Reexport v1.2.2
#   [2f01184e] + SparseArrays v1.10.0
#   [10745b16] + Statistics v1.10.0
#   [bea87d4a] + SuiteSparse_jll v7.2.1+1
# Precompiling project...
#   ✓ FixedPointNumbers
#   ✓ ColorTypes
#   ✓ Colors
#   ✓ PyPlot
#   4 dependencies successfully precompiled in 38 seconds. 23 already precompiled.
#   4 dependencies had output during precompilation:
# ┌ FixedPointNumbers
# ...
